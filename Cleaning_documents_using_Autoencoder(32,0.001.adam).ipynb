# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/denoising-dirty-documents/sampleSubmission.csv
# /kaggle/input/denoising-dirty-documents/test/55.png
# /kaggle/input/denoising-dirty-documents/test/64.png
# /kaggle/input/denoising-dirty-documents/test/106.png
# /kaggle/input/denoising-dirty-documents/test/19.png
# /kaggle/input/denoising-dirty-documents/test/127.png
# /kaggle/input/denoising-dirty-documents/test/133.png
# /kaggle/input/denoising-dirty-documents/test/13.png
# /kaggle/input/denoising-dirty-documents/test/49.png
# /kaggle/input/denoising-dirty-documents/test/121.png
# /kaggle/input/denoising-dirty-documents/test/112.png
# /kaggle/input/denoising-dirty-documents/test/16.png
# /kaggle/input/denoising-dirty-documents/test/58.png
# /kaggle/input/denoising-dirty-documents/test/115.png
# /kaggle/input/denoising-dirty-documents/test/148.png
# /kaggle/input/denoising-dirty-documents/test/28.png
# /kaggle/input/denoising-dirty-documents/test/154.png
# /kaggle/input/denoising-dirty-documents/test/88.png
# /kaggle/input/denoising-dirty-documents/test/25.png
# /kaggle/input/denoising-dirty-documents/test/157.png
# /kaggle/input/denoising-dirty-documents/test/136.png
# /kaggle/input/denoising-dirty-documents/test/118.png
# /kaggle/input/denoising-dirty-documents/test/94.png
# /kaggle/input/denoising-dirty-documents/test/175.png
# /kaggle/input/denoising-dirty-documents/test/31.png
# /kaggle/input/denoising-dirty-documents/test/163.png
# /kaggle/input/denoising-dirty-documents/test/85.png
# /kaggle/input/denoising-dirty-documents/test/124.png
# /kaggle/input/denoising-dirty-documents/test/202.png
# /kaggle/input/denoising-dirty-documents/test/178.png
# /kaggle/input/denoising-dirty-documents/test/103.png
# /kaggle/input/denoising-dirty-documents/test/208.png
# /kaggle/input/denoising-dirty-documents/test/91.png
# /kaggle/input/denoising-dirty-documents/test/169.png
# /kaggle/input/denoising-dirty-documents/test/193.png
# /kaggle/input/denoising-dirty-documents/test/82.png
# /kaggle/input/denoising-dirty-documents/test/10.png
# /kaggle/input/denoising-dirty-documents/test/79.png
# /kaggle/input/denoising-dirty-documents/test/34.png
# /kaggle/input/denoising-dirty-documents/test/70.png
# /kaggle/input/denoising-dirty-documents/test/67.png
# /kaggle/input/denoising-dirty-documents/test/130.png
# /kaggle/input/denoising-dirty-documents/test/166.png
# /kaggle/input/denoising-dirty-documents/test/139.png
# /kaggle/input/denoising-dirty-documents/test/190.png
# /kaggle/input/denoising-dirty-documents/test/181.png
# /kaggle/input/denoising-dirty-documents/test/52.png
# /kaggle/input/denoising-dirty-documents/test/196.png
# /kaggle/input/denoising-dirty-documents/test/199.png
# /kaggle/input/denoising-dirty-documents/test/61.png
# /kaggle/input/denoising-dirty-documents/test/40.png
# /kaggle/input/denoising-dirty-documents/test/100.png
# /kaggle/input/denoising-dirty-documents/test/214.png
# /kaggle/input/denoising-dirty-documents/test/46.png
# /kaggle/input/denoising-dirty-documents/test/160.png
# /kaggle/input/denoising-dirty-documents/test/151.png
# /kaggle/input/denoising-dirty-documents/test/205.png
# /kaggle/input/denoising-dirty-documents/test/184.png
# /kaggle/input/denoising-dirty-documents/test/4.png
# /kaggle/input/denoising-dirty-documents/test/172.png
# /kaggle/input/denoising-dirty-documents/test/7.png
# /kaggle/input/denoising-dirty-documents/test/142.png
# /kaggle/input/denoising-dirty-documents/test/145.png
# /kaggle/input/denoising-dirty-documents/test/22.png
# /kaggle/input/denoising-dirty-documents/test/43.png
# /kaggle/input/denoising-dirty-documents/test/73.png
# /kaggle/input/denoising-dirty-documents/test/97.png
# /kaggle/input/denoising-dirty-documents/test/1.png
# /kaggle/input/denoising-dirty-documents/test/37.png
# /kaggle/input/denoising-dirty-documents/test/109.png
# /kaggle/input/denoising-dirty-documents/test/187.png
# /kaggle/input/denoising-dirty-documents/test/211.png
# /kaggle/input/denoising-dirty-documents/test/76.png
# /kaggle/input/denoising-dirty-documents/test/test/55.png
# /kaggle/input/denoising-dirty-documents/test/test/64.png
# /kaggle/input/denoising-dirty-documents/test/test/106.png
# /kaggle/input/denoising-dirty-documents/test/test/19.png
# /kaggle/input/denoising-dirty-documents/test/test/127.png
# /kaggle/input/denoising-dirty-documents/test/test/133.png
# /kaggle/input/denoising-dirty-documents/test/test/13.png
# /kaggle/input/denoising-dirty-documents/test/test/49.png
# /kaggle/input/denoising-dirty-documents/test/test/121.png
# /kaggle/input/denoising-dirty-documents/test/test/112.png
# /kaggle/input/denoising-dirty-documents/test/test/16.png
# /kaggle/input/denoising-dirty-documents/test/test/58.png
# /kaggle/input/denoising-dirty-documents/test/test/115.png
# /kaggle/input/denoising-dirty-documents/test/test/148.png
# /kaggle/input/denoising-dirty-documents/test/test/28.png
# /kaggle/input/denoising-dirty-documents/test/test/154.png
# /kaggle/input/denoising-dirty-documents/test/test/88.png
# /kaggle/input/denoising-dirty-documents/test/test/25.png
# /kaggle/input/denoising-dirty-documents/test/test/157.png
# /kaggle/input/denoising-dirty-documents/test/test/136.png
# /kaggle/input/denoising-dirty-documents/test/test/118.png
# /kaggle/input/denoising-dirty-documents/test/test/94.png
# /kaggle/input/denoising-dirty-documents/test/test/175.png
# /kaggle/input/denoising-dirty-documents/test/test/31.png
# /kaggle/input/denoising-dirty-documents/test/test/163.png
# /kaggle/input/denoising-dirty-documents/test/test/85.png
# /kaggle/input/denoising-dirty-documents/test/test/124.png
# /kaggle/input/denoising-dirty-documents/test/test/202.png
# /kaggle/input/denoising-dirty-documents/test/test/178.png
# /kaggle/input/denoising-dirty-documents/test/test/103.png
# /kaggle/input/denoising-dirty-documents/test/test/208.png
# /kaggle/input/denoising-dirty-documents/test/test/91.png
# /kaggle/input/denoising-dirty-documents/test/test/169.png
# /kaggle/input/denoising-dirty-documents/test/test/193.png
# /kaggle/input/denoising-dirty-documents/test/test/82.png
# /kaggle/input/denoising-dirty-documents/test/test/10.png
# /kaggle/input/denoising-dirty-documents/test/test/79.png
# /kaggle/input/denoising-dirty-documents/test/test/34.png
# /kaggle/input/denoising-dirty-documents/test/test/70.png
# /kaggle/input/denoising-dirty-documents/test/test/67.png
# /kaggle/input/denoising-dirty-documents/test/test/130.png
# /kaggle/input/denoising-dirty-documents/test/test/166.png
# /kaggle/input/denoising-dirty-documents/test/test/139.png
# /kaggle/input/denoising-dirty-documents/test/test/190.png
# /kaggle/input/denoising-dirty-documents/test/test/181.png
# /kaggle/input/denoising-dirty-documents/test/test/52.png
# /kaggle/input/denoising-dirty-documents/test/test/196.png
# /kaggle/input/denoising-dirty-documents/test/test/199.png
# /kaggle/input/denoising-dirty-documents/test/test/61.png
# /kaggle/input/denoising-dirty-documents/test/test/40.png
# /kaggle/input/denoising-dirty-documents/test/test/100.png
# /kaggle/input/denoising-dirty-documents/test/test/214.png
# /kaggle/input/denoising-dirty-documents/test/test/46.png
# /kaggle/input/denoising-dirty-documents/test/test/160.png
# /kaggle/input/denoising-dirty-documents/test/test/151.png
# /kaggle/input/denoising-dirty-documents/test/test/205.png
# /kaggle/input/denoising-dirty-documents/test/test/184.png
# /kaggle/input/denoising-dirty-documents/test/test/4.png
# /kaggle/input/denoising-dirty-documents/test/test/172.png
# /kaggle/input/denoising-dirty-documents/test/test/7.png
# /kaggle/input/denoising-dirty-documents/test/test/142.png
# /kaggle/input/denoising-dirty-documents/test/test/145.png
# /kaggle/input/denoising-dirty-documents/test/test/22.png
# /kaggle/input/denoising-dirty-documents/test/test/43.png
# /kaggle/input/denoising-dirty-documents/test/test/73.png
# /kaggle/input/denoising-dirty-documents/test/test/97.png
# /kaggle/input/denoising-dirty-documents/test/test/1.png
# /kaggle/input/denoising-dirty-documents/test/test/37.png
# /kaggle/input/denoising-dirty-documents/test/test/109.png
# /kaggle/input/denoising-dirty-documents/test/test/187.png
# /kaggle/input/denoising-dirty-documents/test/test/211.png
# /kaggle/input/denoising-dirty-documents/test/test/76.png
# /kaggle/input/denoising-dirty-documents/train/147.png
# /kaggle/input/denoising-dirty-documents/train/75.png
# /kaggle/input/denoising-dirty-documents/train/168.png
# /kaggle/input/denoising-dirty-documents/train/177.png
# /kaggle/input/denoising-dirty-documents/train/39.png
# /kaggle/input/denoising-dirty-documents/train/188.png
# /kaggle/input/denoising-dirty-documents/train/140.png
# /kaggle/input/denoising-dirty-documents/train/215.png
# /kaggle/input/denoising-dirty-documents/train/182.png
# /kaggle/input/denoising-dirty-documents/train/122.png
# /kaggle/input/denoising-dirty-documents/train/204.png
# /kaggle/input/denoising-dirty-documents/train/96.png
# /kaggle/input/denoising-dirty-documents/train/51.png
# /kaggle/input/denoising-dirty-documents/train/125.png
# /kaggle/input/denoising-dirty-documents/train/171.png
# /kaggle/input/denoising-dirty-documents/train/62.png
# /kaggle/input/denoising-dirty-documents/train/93.png
# /kaggle/input/denoising-dirty-documents/train/27.png
# /kaggle/input/denoising-dirty-documents/train/102.png
# /kaggle/input/denoising-dirty-documents/train/63.png
# /kaggle/input/denoising-dirty-documents/train/185.png
# /kaggle/input/denoising-dirty-documents/train/41.png
# /kaggle/input/denoising-dirty-documents/train/101.png
# /kaggle/input/denoising-dirty-documents/train/179.png
# /kaggle/input/denoising-dirty-documents/train/90.png
# /kaggle/input/denoising-dirty-documents/train/65.png
# /kaggle/input/denoising-dirty-documents/train/32.png
# /kaggle/input/denoising-dirty-documents/train/210.png
# /kaggle/input/denoising-dirty-documents/train/189.png
# /kaggle/input/denoising-dirty-documents/train/176.png
# /kaggle/input/denoising-dirty-documents/train/131.png
# /kaggle/input/denoising-dirty-documents/train/167.png
# /kaggle/input/denoising-dirty-documents/train/114.png
# /kaggle/input/denoising-dirty-documents/train/165.png
# /kaggle/input/denoising-dirty-documents/train/200.png
# /kaggle/input/denoising-dirty-documents/train/209.png
# /kaggle/input/denoising-dirty-documents/train/155.png
# /kaggle/input/denoising-dirty-documents/train/156.png
# /kaggle/input/denoising-dirty-documents/train/95.png
# /kaggle/input/denoising-dirty-documents/train/26.png
# /kaggle/input/denoising-dirty-documents/train/174.png
# /kaggle/input/denoising-dirty-documents/train/66.png
# /kaggle/input/denoising-dirty-documents/train/203.png
# /kaggle/input/denoising-dirty-documents/train/92.png
# /kaggle/input/denoising-dirty-documents/train/111.png
# /kaggle/input/denoising-dirty-documents/train/38.png
# /kaggle/input/denoising-dirty-documents/train/126.png
# /kaggle/input/denoising-dirty-documents/train/72.png
# /kaggle/input/denoising-dirty-documents/train/77.png
# /kaggle/input/denoising-dirty-documents/train/138.png
# /kaggle/input/denoising-dirty-documents/train/17.png
# /kaggle/input/denoising-dirty-documents/train/69.png
# /kaggle/input/denoising-dirty-documents/train/107.png
# /kaggle/input/denoising-dirty-documents/train/141.png
# /kaggle/input/denoising-dirty-documents/train/89.png
# /kaggle/input/denoising-dirty-documents/train/191.png
# /kaggle/input/denoising-dirty-documents/train/60.png
# /kaggle/input/denoising-dirty-documents/train/149.png
# /kaggle/input/denoising-dirty-documents/train/83.png
# /kaggle/input/denoising-dirty-documents/train/146.png
# /kaggle/input/denoising-dirty-documents/train/3.png
# /kaggle/input/denoising-dirty-documents/train/105.png
# /kaggle/input/denoising-dirty-documents/train/212.png
# /kaggle/input/denoising-dirty-documents/train/206.png
# /kaggle/input/denoising-dirty-documents/train/164.png
# /kaggle/input/denoising-dirty-documents/train/108.png
# /kaggle/input/denoising-dirty-documents/train/42.png
# /kaggle/input/denoising-dirty-documents/train/110.png
# /kaggle/input/denoising-dirty-documents/train/21.png
# /kaggle/input/denoising-dirty-documents/train/48.png
# /kaggle/input/denoising-dirty-documents/train/159.png
# /kaggle/input/denoising-dirty-documents/train/33.png
# /kaggle/input/denoising-dirty-documents/train/137.png
# /kaggle/input/denoising-dirty-documents/train/8.png
# /kaggle/input/denoising-dirty-documents/train/56.png
# /kaggle/input/denoising-dirty-documents/train/68.png
# /kaggle/input/denoising-dirty-documents/train/129.png
# /kaggle/input/denoising-dirty-documents/train/104.png
# /kaggle/input/denoising-dirty-documents/train/213.png
# /kaggle/input/denoising-dirty-documents/train/194.png
# /kaggle/input/denoising-dirty-documents/train/198.png
# /kaggle/input/denoising-dirty-documents/train/53.png
# /kaggle/input/denoising-dirty-documents/train/84.png
# /kaggle/input/denoising-dirty-documents/train/120.png
# /kaggle/input/denoising-dirty-documents/train/12.png
# /kaggle/input/denoising-dirty-documents/train/98.png
# /kaggle/input/denoising-dirty-documents/train/11.png
# /kaggle/input/denoising-dirty-documents/train/153.png
# /kaggle/input/denoising-dirty-documents/train/180.png
# /kaggle/input/denoising-dirty-documents/train/123.png
# /kaggle/input/denoising-dirty-documents/train/158.png
# /kaggle/input/denoising-dirty-documents/train/78.png
# /kaggle/input/denoising-dirty-documents/train/18.png
# /kaggle/input/denoising-dirty-documents/train/170.png
# /kaggle/input/denoising-dirty-documents/train/9.png
# /kaggle/input/denoising-dirty-documents/train/71.png
# /kaggle/input/denoising-dirty-documents/train/30.png
# /kaggle/input/denoising-dirty-documents/train/116.png
# /kaggle/input/denoising-dirty-documents/train/80.png
# /kaggle/input/denoising-dirty-documents/train/161.png
# /kaggle/input/denoising-dirty-documents/train/5.png
# /kaggle/input/denoising-dirty-documents/train/192.png
# /kaggle/input/denoising-dirty-documents/train/143.png
# /kaggle/input/denoising-dirty-documents/train/87.png
# /kaggle/input/denoising-dirty-documents/train/15.png
# /kaggle/input/denoising-dirty-documents/train/117.png
# /kaggle/input/denoising-dirty-documents/train/36.png
# /kaggle/input/denoising-dirty-documents/train/59.png
# /kaggle/input/denoising-dirty-documents/train/44.png
# /kaggle/input/denoising-dirty-documents/train/54.png
# /kaggle/input/denoising-dirty-documents/train/152.png
# /kaggle/input/denoising-dirty-documents/train/173.png
# /kaggle/input/denoising-dirty-documents/train/50.png
# /kaggle/input/denoising-dirty-documents/train/201.png
# /kaggle/input/denoising-dirty-documents/train/74.png
# /kaggle/input/denoising-dirty-documents/train/197.png
# /kaggle/input/denoising-dirty-documents/train/14.png
# /kaggle/input/denoising-dirty-documents/train/135.png
# /kaggle/input/denoising-dirty-documents/train/128.png
# /kaggle/input/denoising-dirty-documents/train/45.png
# /kaggle/input/denoising-dirty-documents/train/99.png
# /kaggle/input/denoising-dirty-documents/train/35.png
# /kaggle/input/denoising-dirty-documents/train/132.png
# /kaggle/input/denoising-dirty-documents/train/47.png
# /kaggle/input/denoising-dirty-documents/train/119.png
# /kaggle/input/denoising-dirty-documents/train/23.png
# /kaggle/input/denoising-dirty-documents/train/183.png
# /kaggle/input/denoising-dirty-documents/train/207.png
# /kaggle/input/denoising-dirty-documents/train/81.png
# /kaggle/input/denoising-dirty-documents/train/216.png
# /kaggle/input/denoising-dirty-documents/train/2.png
# /kaggle/input/denoising-dirty-documents/train/162.png
# /kaggle/input/denoising-dirty-documents/train/20.png
# /kaggle/input/denoising-dirty-documents/train/113.png
# /kaggle/input/denoising-dirty-documents/train/150.png
# /kaggle/input/denoising-dirty-documents/train/144.png
# /kaggle/input/denoising-dirty-documents/train/29.png
# /kaggle/input/denoising-dirty-documents/train/134.png
# /kaggle/input/denoising-dirty-documents/train/186.png
# /kaggle/input/denoising-dirty-documents/train/86.png
# /kaggle/input/denoising-dirty-documents/train/57.png
# /kaggle/input/denoising-dirty-documents/train/195.png
# /kaggle/input/denoising-dirty-documents/train/6.png
# /kaggle/input/denoising-dirty-documents/train/24.png
# /kaggle/input/denoising-dirty-documents/train/train/147.png
# /kaggle/input/denoising-dirty-documents/train/train/75.png
# /kaggle/input/denoising-dirty-documents/train/train/168.png
# /kaggle/input/denoising-dirty-documents/train/train/177.png
# /kaggle/input/denoising-dirty-documents/train/train/39.png
# /kaggle/input/denoising-dirty-documents/train/train/188.png
# /kaggle/input/denoising-dirty-documents/train/train/140.png
# /kaggle/input/denoising-dirty-documents/train/train/215.png
# /kaggle/input/denoising-dirty-documents/train/train/182.png
# /kaggle/input/denoising-dirty-documents/train/train/122.png
# /kaggle/input/denoising-dirty-documents/train/train/204.png
# /kaggle/input/denoising-dirty-documents/train/train/96.png
# /kaggle/input/denoising-dirty-documents/train/train/51.png
# /kaggle/input/denoising-dirty-documents/train/train/125.png
# /kaggle/input/denoising-dirty-documents/train/train/171.png
# /kaggle/input/denoising-dirty-documents/train/train/62.png
# /kaggle/input/denoising-dirty-documents/train/train/93.png
# /kaggle/input/denoising-dirty-documents/train/train/27.png
# /kaggle/input/denoising-dirty-documents/train/train/102.png
# /kaggle/input/denoising-dirty-documents/train/train/63.png
# /kaggle/input/denoising-dirty-documents/train/train/185.png
# /kaggle/input/denoising-dirty-documents/train/train/41.png
# /kaggle/input/denoising-dirty-documents/train/train/101.png
# /kaggle/input/denoising-dirty-documents/train/train/179.png
# /kaggle/input/denoising-dirty-documents/train/train/90.png
# /kaggle/input/denoising-dirty-documents/train/train/65.png
# /kaggle/input/denoising-dirty-documents/train/train/32.png
# /kaggle/input/denoising-dirty-documents/train/train/210.png
# /kaggle/input/denoising-dirty-documents/train/train/189.png
# /kaggle/input/denoising-dirty-documents/train/train/176.png
# /kaggle/input/denoising-dirty-documents/train/train/131.png
# /kaggle/input/denoising-dirty-documents/train/train/167.png
# /kaggle/input/denoising-dirty-documents/train/train/114.png
# /kaggle/input/denoising-dirty-documents/train/train/165.png
# /kaggle/input/denoising-dirty-documents/train/train/200.png
# /kaggle/input/denoising-dirty-documents/train/train/209.png
# /kaggle/input/denoising-dirty-documents/train/train/155.png
# /kaggle/input/denoising-dirty-documents/train/train/156.png
# /kaggle/input/denoising-dirty-documents/train/train/95.png
# /kaggle/input/denoising-dirty-documents/train/train/26.png
# /kaggle/input/denoising-dirty-documents/train/train/174.png
# /kaggle/input/denoising-dirty-documents/train/train/66.png
# /kaggle/input/denoising-dirty-documents/train/train/203.png
# /kaggle/input/denoising-dirty-documents/train/train/92.png
# /kaggle/input/denoising-dirty-documents/train/train/111.png
# /kaggle/input/denoising-dirty-documents/train/train/38.png
# /kaggle/input/denoising-dirty-documents/train/train/126.png
# /kaggle/input/denoising-dirty-documents/train/train/72.png
# /kaggle/input/denoising-dirty-documents/train/train/77.png
# /kaggle/input/denoising-dirty-documents/train/train/138.png
# /kaggle/input/denoising-dirty-documents/train/train/17.png
# /kaggle/input/denoising-dirty-documents/train/train/69.png
# /kaggle/input/denoising-dirty-documents/train/train/107.png
# /kaggle/input/denoising-dirty-documents/train/train/141.png
# /kaggle/input/denoising-dirty-documents/train/train/89.png
# /kaggle/input/denoising-dirty-documents/train/train/191.png
# /kaggle/input/denoising-dirty-documents/train/train/60.png
# /kaggle/input/denoising-dirty-documents/train/train/149.png
# /kaggle/input/denoising-dirty-documents/train/train/83.png
# /kaggle/input/denoising-dirty-documents/train/train/146.png
# /kaggle/input/denoising-dirty-documents/train/train/3.png
# /kaggle/input/denoising-dirty-documents/train/train/105.png
# /kaggle/input/denoising-dirty-documents/train/train/212.png
# /kaggle/input/denoising-dirty-documents/train/train/206.png
# /kaggle/input/denoising-dirty-documents/train/train/164.png
# /kaggle/input/denoising-dirty-documents/train/train/108.png
# /kaggle/input/denoising-dirty-documents/train/train/42.png
# /kaggle/input/denoising-dirty-documents/train/train/110.png
# /kaggle/input/denoising-dirty-documents/train/train/21.png
# /kaggle/input/denoising-dirty-documents/train/train/48.png
# /kaggle/input/denoising-dirty-documents/train/train/159.png
# /kaggle/input/denoising-dirty-documents/train/train/33.png
# /kaggle/input/denoising-dirty-documents/train/train/137.png
# /kaggle/input/denoising-dirty-documents/train/train/8.png
# /kaggle/input/denoising-dirty-documents/train/train/56.png
# /kaggle/input/denoising-dirty-documents/train/train/68.png
# /kaggle/input/denoising-dirty-documents/train/train/129.png
# /kaggle/input/denoising-dirty-documents/train/train/104.png
# /kaggle/input/denoising-dirty-documents/train/train/213.png
# /kaggle/input/denoising-dirty-documents/train/train/194.png
# /kaggle/input/denoising-dirty-documents/train/train/198.png
# /kaggle/input/denoising-dirty-documents/train/train/53.png
# /kaggle/input/denoising-dirty-documents/train/train/84.png
# /kaggle/input/denoising-dirty-documents/train/train/120.png
# /kaggle/input/denoising-dirty-documents/train/train/12.png
# /kaggle/input/denoising-dirty-documents/train/train/98.png
# /kaggle/input/denoising-dirty-documents/train/train/11.png
# /kaggle/input/denoising-dirty-documents/train/train/153.png
# /kaggle/input/denoising-dirty-documents/train/train/180.png
# /kaggle/input/denoising-dirty-documents/train/train/123.png
# /kaggle/input/denoising-dirty-documents/train/train/158.png
# /kaggle/input/denoising-dirty-documents/train/train/78.png
# /kaggle/input/denoising-dirty-documents/train/train/18.png
# /kaggle/input/denoising-dirty-documents/train/train/170.png
# /kaggle/input/denoising-dirty-documents/train/train/9.png
# /kaggle/input/denoising-dirty-documents/train/train/71.png
# /kaggle/input/denoising-dirty-documents/train/train/30.png
# /kaggle/input/denoising-dirty-documents/train/train/116.png
# /kaggle/input/denoising-dirty-documents/train/train/80.png
# /kaggle/input/denoising-dirty-documents/train/train/161.png
# /kaggle/input/denoising-dirty-documents/train/train/5.png
# /kaggle/input/denoising-dirty-documents/train/train/192.png
# /kaggle/input/denoising-dirty-documents/train/train/143.png
# /kaggle/input/denoising-dirty-documents/train/train/87.png
# /kaggle/input/denoising-dirty-documents/train/train/15.png
# /kaggle/input/denoising-dirty-documents/train/train/117.png
# /kaggle/input/denoising-dirty-documents/train/train/36.png
# /kaggle/input/denoising-dirty-documents/train/train/59.png
# /kaggle/input/denoising-dirty-documents/train/train/44.png
# /kaggle/input/denoising-dirty-documents/train/train/54.png
# /kaggle/input/denoising-dirty-documents/train/train/152.png
# /kaggle/input/denoising-dirty-documents/train/train/173.png
# /kaggle/input/denoising-dirty-documents/train/train/50.png
# /kaggle/input/denoising-dirty-documents/train/train/201.png
# /kaggle/input/denoising-dirty-documents/train/train/74.png
# /kaggle/input/denoising-dirty-documents/train/train/197.png
# /kaggle/input/denoising-dirty-documents/train/train/14.png
# /kaggle/input/denoising-dirty-documents/train/train/135.png
# /kaggle/input/denoising-dirty-documents/train/train/128.png
# /kaggle/input/denoising-dirty-documents/train/train/45.png
# /kaggle/input/denoising-dirty-documents/train/train/99.png
# /kaggle/input/denoising-dirty-documents/train/train/35.png
# /kaggle/input/denoising-dirty-documents/train/train/132.png
# /kaggle/input/denoising-dirty-documents/train/train/47.png
# /kaggle/input/denoising-dirty-documents/train/train/119.png
# /kaggle/input/denoising-dirty-documents/train/train/23.png
# /kaggle/input/denoising-dirty-documents/train/train/183.png
# /kaggle/input/denoising-dirty-documents/train/train/207.png
# /kaggle/input/denoising-dirty-documents/train/train/81.png
# /kaggle/input/denoising-dirty-documents/train/train/216.png
# /kaggle/input/denoising-dirty-documents/train/train/2.png
# /kaggle/input/denoising-dirty-documents/train/train/162.png
# /kaggle/input/denoising-dirty-documents/train/train/20.png
# /kaggle/input/denoising-dirty-documents/train/train/113.png
# /kaggle/input/denoising-dirty-documents/train/train/150.png
# /kaggle/input/denoising-dirty-documents/train/train/144.png
# /kaggle/input/denoising-dirty-documents/train/train/29.png
# /kaggle/input/denoising-dirty-documents/train/train/134.png
# /kaggle/input/denoising-dirty-documents/train/train/186.png
# /kaggle/input/denoising-dirty-documents/train/train/86.png
# /kaggle/input/denoising-dirty-documents/train/train/57.png
# /kaggle/input/denoising-dirty-documents/train/train/195.png
# /kaggle/input/denoising-dirty-documents/train/train/6.png
# /kaggle/input/denoising-dirty-documents/train/train/24.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/147.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/75.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/168.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/177.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/39.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/188.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/140.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/215.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/182.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/122.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/204.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/96.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/51.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/125.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/171.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/62.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/93.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/27.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/102.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/63.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/185.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/41.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/101.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/179.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/90.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/65.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/32.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/210.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/189.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/176.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/131.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/167.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/114.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/165.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/200.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/209.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/155.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/156.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/95.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/26.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/174.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/66.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/203.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/92.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/111.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/38.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/126.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/72.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/77.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/138.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/17.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/69.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/107.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/141.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/89.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/191.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/60.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/149.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/83.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/146.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/3.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/105.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/212.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/206.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/164.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/108.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/42.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/110.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/21.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/48.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/159.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/33.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/137.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/8.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/56.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/68.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/129.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/104.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/213.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/194.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/198.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/53.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/84.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/120.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/12.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/98.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/11.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/153.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/180.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/123.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/158.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/78.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/18.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/170.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/9.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/71.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/30.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/116.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/80.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/161.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/5.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/192.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/143.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/87.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/15.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/117.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/36.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/59.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/44.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/54.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/152.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/173.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/50.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/201.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/74.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/197.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/14.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/135.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/128.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/45.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/99.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/35.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/132.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/47.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/119.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/23.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/183.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/207.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/81.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/216.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/2.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/162.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/20.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/113.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/150.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/144.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/29.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/134.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/186.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/86.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/57.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/195.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/6.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/24.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/147.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/75.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/168.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/177.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/39.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/188.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/140.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/215.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/182.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/122.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/204.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/96.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/51.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/125.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/171.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/62.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/93.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/27.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/102.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/63.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/185.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/41.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/101.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/179.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/90.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/65.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/32.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/210.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/189.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/176.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/131.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/167.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/114.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/165.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/200.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/209.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/155.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/156.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/95.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/26.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/174.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/66.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/203.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/92.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/111.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/38.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/126.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/72.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/77.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/138.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/17.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/69.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/107.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/141.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/89.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/191.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/60.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/149.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/83.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/146.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/3.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/105.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/212.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/206.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/164.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/108.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/42.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/110.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/21.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/48.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/159.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/33.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/137.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/8.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/56.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/68.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/129.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/104.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/213.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/194.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/198.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/53.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/84.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/120.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/12.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/98.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/11.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/153.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/180.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/123.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/158.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/78.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/18.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/170.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/9.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/71.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/30.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/116.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/80.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/161.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/5.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/192.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/143.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/87.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/15.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/117.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/36.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/59.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/44.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/54.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/152.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/173.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/50.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/201.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/74.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/197.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/14.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/135.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/128.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/45.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/99.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/35.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/132.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/47.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/119.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/23.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/183.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/207.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/81.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/216.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/2.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/162.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/20.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/113.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/150.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/144.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/29.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/134.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/186.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/86.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/57.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/195.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/6.png
# /kaggle/input/denoising-dirty-documents/train_cleaned/train_cleaned/24.png

# %%
import os
import glob
import cv2
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from keras.preprocessing import image
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.layers import Input, Dense, Activation, BatchNormalization, Flatten, Conv2D
from keras.layers import MaxPooling2D, Dropout, UpSampling2D
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
training_images = glob.glob('/kaggle/input/denoising-dirty-documents/train/*.png')
cleaned_images = glob.glob('/kaggle/input/denoising-dirty-documents/train_cleaned/*.png')
test_images = glob.glob('/kaggle/input/denoising-dirty-documents/test/*.png')

# %%
def load_image(path):
    image_list = np.zeros((len(path), 258, 540, 1))
    for i, fig in enumerate(path):
        img = image.load_img(fig, color_mode='grayscale', target_size=(258, 540))
        x = image.img_to_array(img).astype('float32')
        x = x / 255.0
        image_list[i] = x
    
    return image_list

x_train = load_image(training_images)
y_train = load_image(cleaned_images)
x_test = load_image(test_images)

print(x_train.shape, x_test.shape)
# Out:
# (144, 258, 540, 1) (72, 258, 540, 1)

# %%
def train_val_split(x_train, y_train):
    rnd = np.random.RandomState(seed=42)
    perm = rnd.permutation(len(x_train))
    train_idx = perm[:int(0.8 * len(x_train))]
    val_idx = perm[int(0.8 * len(x_train)):]
    return x_train[train_idx], y_train[train_idx], x_train[val_idx], y_train[val_idx]

x_train, y_train, x_val, y_val = train_val_split(x_train, y_train)
print(x_train.shape, x_val.shape)
# Out:
# (115, 258, 540, 1) (29, 258, 540, 1)

# %%
img_rows = 258
img_cols = 540
channels = 1
img_shape = (img_rows, img_cols, channels)

# %%
input_layer = Input(shape=img_shape)
        
# encoder
x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer)
x = MaxPooling2D((2, 2), padding='same')(x)

# decoder
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)


output_layer = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
        
early_stopping = EarlyStopping(monitor='val_loss',
                                       min_delta=0,
                                       patience=20,
                                       verbose=1, 
                                       mode='auto')

autoencoder_model =Model(input_layer, output_layer)
autoencoder_model.compile(loss='mse', optimizer=Adam(lr=0.001))
history = autoencoder_model.fit(x_train, y_train,
                                             batch_size=32,
                                             epochs=200,
                                             validation_data=(x_val, y_val),
                                             callbacks=[early_stopping])
autoencoder_model.summary()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

preds = autoencoder_model.predict(x_test)
# Out:
# Train on 115 samples, validate on 29 samples
# Epoch 1/200
# 115/115 [==============================] - 6s 56ms/step - loss: 0.1385 - val_loss: 0.0775
# Epoch 2/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0735 - val_loss: 0.0691
# Epoch 3/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0713 - val_loss: 0.0724
# Epoch 4/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0739 - val_loss: 0.0736
# Epoch 5/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0744 - val_loss: 0.0728
# Epoch 6/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0730 - val_loss: 0.0703
# Epoch 7/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0698 - val_loss: 0.0663
# Epoch 8/200
# 115/115 [==============================] - 1s 5ms/step - loss: 0.0662 - val_loss: 0.0647
# Epoch 9/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0657 - val_loss: 0.0638
# Epoch 10/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0635 - val_loss: 0.0610
# Epoch 11/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0608 - val_loss: 0.0587
# Epoch 12/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0580 - val_loss: 0.0554
# Epoch 13/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0548 - val_loss: 0.0524
# Epoch 14/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0515 - val_loss: 0.0496
# Epoch 15/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0483 - val_loss: 0.0461
# Epoch 16/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0452 - val_loss: 0.0434
# Epoch 17/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0425 - val_loss: 0.0408
# Epoch 18/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0401 - val_loss: 0.0385
# Epoch 19/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0380 - val_loss: 0.0366
# Epoch 20/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0359 - val_loss: 0.0347
# Epoch 21/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0342 - val_loss: 0.0330
# Epoch 22/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0325 - val_loss: 0.0313
# Epoch 23/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0310 - val_loss: 0.0299
# Epoch 24/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0296 - val_loss: 0.0286
# Epoch 25/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0284 - val_loss: 0.0274
# Epoch 26/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0272 - val_loss: 0.0263
# Epoch 27/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0262 - val_loss: 0.0253
# Epoch 28/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0252 - val_loss: 0.0245
# Epoch 29/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0243 - val_loss: 0.0236
# Epoch 30/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0234 - val_loss: 0.0229
# Epoch 31/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0226 - val_loss: 0.0221
# Epoch 32/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0218 - val_loss: 0.0214
# Epoch 33/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0210 - val_loss: 0.0207
# Epoch 34/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0203 - val_loss: 0.0200
# Epoch 35/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0195 - val_loss: 0.0193
# Epoch 36/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0188 - val_loss: 0.0188
# Epoch 37/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0181 - val_loss: 0.0181
# Epoch 38/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0175 - val_loss: 0.0176
# Epoch 39/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0171 - val_loss: 0.0171
# Epoch 40/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0166 - val_loss: 0.0167
# Epoch 41/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0161 - val_loss: 0.0166
# Epoch 42/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0158 - val_loss: 0.0160
# Epoch 43/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0153 - val_loss: 0.0157
# Epoch 44/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0150 - val_loss: 0.0152
# Epoch 45/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0146 - val_loss: 0.0149
# Epoch 46/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0143 - val_loss: 0.0147
# Epoch 47/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0140 - val_loss: 0.0144
# Epoch 48/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0137 - val_loss: 0.0141
# Epoch 49/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0135 - val_loss: 0.0139
# Epoch 50/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0133 - val_loss: 0.0137
# Epoch 51/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0130 - val_loss: 0.0135
# Epoch 52/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0128 - val_loss: 0.0133
# Epoch 53/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0126 - val_loss: 0.0131
# Epoch 54/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0124 - val_loss: 0.0129
# Epoch 55/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0122 - val_loss: 0.0127
# Epoch 56/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0121 - val_loss: 0.0125
# Epoch 57/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0119 - val_loss: 0.0123
# Epoch 58/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0117 - val_loss: 0.0122
# Epoch 59/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0115 - val_loss: 0.0120
# Epoch 60/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0114 - val_loss: 0.0119
# Epoch 61/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0113 - val_loss: 0.0118
# Epoch 62/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0111 - val_loss: 0.0116
# Epoch 63/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0109 - val_loss: 0.0115
# Epoch 64/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0108 - val_loss: 0.0113
# Epoch 65/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0107 - val_loss: 0.0112
# Epoch 66/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0105 - val_loss: 0.0111
# Epoch 67/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0104 - val_loss: 0.0110
# Epoch 68/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0103 - val_loss: 0.0109
# Epoch 69/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0102 - val_loss: 0.0107
# Epoch 70/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0101 - val_loss: 0.0106
# Epoch 71/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0100 - val_loss: 0.0106
# Epoch 72/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 73/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0097 - val_loss: 0.0103
# Epoch 74/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0097 - val_loss: 0.0102
# Epoch 75/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0096 - val_loss: 0.0101
# Epoch 76/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0095 - val_loss: 0.0100
# Epoch 77/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0094 - val_loss: 0.0099
# Epoch 78/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0093 - val_loss: 0.0099
# Epoch 79/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0093 - val_loss: 0.0100
# Epoch 80/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0092 - val_loss: 0.0097
# Epoch 81/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0091 - val_loss: 0.0096
# Epoch 82/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0090 - val_loss: 0.0095
# Epoch 83/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0089 - val_loss: 0.0094
# Epoch 84/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0088 - val_loss: 0.0093
# Epoch 85/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0087 - val_loss: 0.0093
# Epoch 86/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0087 - val_loss: 0.0092
# Epoch 87/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0086 - val_loss: 0.0091
# Epoch 88/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0085 - val_loss: 0.0090
# Epoch 89/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0085 - val_loss: 0.0090
# Epoch 90/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0084 - val_loss: 0.0090
# Epoch 91/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0083 - val_loss: 0.0089
# Epoch 92/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0083 - val_loss: 0.0088
# Epoch 93/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0082 - val_loss: 0.0087
# Epoch 94/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0081 - val_loss: 0.0087
# Epoch 95/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0081 - val_loss: 0.0086
# Epoch 96/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0080 - val_loss: 0.0086
# Epoch 97/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0080 - val_loss: 0.0086
# Epoch 98/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0080 - val_loss: 0.0085
# Epoch 99/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0079 - val_loss: 0.0084
# Epoch 100/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0078 - val_loss: 0.0083
# Epoch 101/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0078 - val_loss: 0.0083
# Epoch 102/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0077 - val_loss: 0.0082
# Epoch 103/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0076 - val_loss: 0.0082
# Epoch 104/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0076 - val_loss: 0.0081
# Epoch 105/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0076 - val_loss: 0.0081
# Epoch 106/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0075 - val_loss: 0.0080
# Epoch 107/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0075 - val_loss: 0.0080
# Epoch 108/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0075 - val_loss: 0.0080
# Epoch 109/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0074 - val_loss: 0.0080
# Epoch 110/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0074 - val_loss: 0.0079
# Epoch 111/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0073 - val_loss: 0.0078
# Epoch 112/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0073 - val_loss: 0.0077
# Epoch 113/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0072 - val_loss: 0.0077
# Epoch 114/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0072 - val_loss: 0.0077
# Epoch 115/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0071 - val_loss: 0.0077
# Epoch 116/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0071 - val_loss: 0.0076
# Epoch 117/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0071 - val_loss: 0.0076
# Epoch 118/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0070 - val_loss: 0.0075
# Epoch 119/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0070 - val_loss: 0.0075
# Epoch 120/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0069 - val_loss: 0.0075
# Epoch 121/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0069 - val_loss: 0.0074
# Epoch 122/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0068 - val_loss: 0.0074
# Epoch 123/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0068 - val_loss: 0.0073
# Epoch 124/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0068 - val_loss: 0.0074
# Epoch 125/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0068 - val_loss: 0.0073
# Epoch 126/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0068 - val_loss: 0.0072
# Epoch 127/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0067 - val_loss: 0.0072
# Epoch 128/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 129/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 130/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 131/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 132/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0065 - val_loss: 0.0070
# Epoch 133/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 134/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 135/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 136/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0065 - val_loss: 0.0069
# Epoch 137/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0064 - val_loss: 0.0068
# Epoch 138/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 139/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0063 - val_loss: 0.0068
# Epoch 140/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0063 - val_loss: 0.0067
# Epoch 141/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0062 - val_loss: 0.0067
# Epoch 142/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0062 - val_loss: 0.0067
# Epoch 143/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0062 - val_loss: 0.0066
# Epoch 144/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0061 - val_loss: 0.0066
# Epoch 145/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0061 - val_loss: 0.0066
# Epoch 146/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0061 - val_loss: 0.0065
# Epoch 147/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0061 - val_loss: 0.0065
# Epoch 148/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0061 - val_loss: 0.0066
# Epoch 149/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0061 - val_loss: 0.0065
# Epoch 150/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0060 - val_loss: 0.0066
# Epoch 151/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 152/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0060 - val_loss: 0.0064
# Epoch 153/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0059 - val_loss: 0.0063
# Epoch 154/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0059 - val_loss: 0.0063
# Epoch 155/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0059 - val_loss: 0.0063
# Epoch 156/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 157/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 158/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 159/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 160/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 161/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0058 - val_loss: 0.0062
# Epoch 162/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0057 - val_loss: 0.0061
# Epoch 163/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0057 - val_loss: 0.0061
# Epoch 164/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0056 - val_loss: 0.0061
# Epoch 165/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0056 - val_loss: 0.0060
# Epoch 166/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0056 - val_loss: 0.0060
# Epoch 167/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0056 - val_loss: 0.0060
# Epoch 168/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 169/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 170/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0056 - val_loss: 0.0060
# Epoch 171/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0055 - val_loss: 0.0059
# Epoch 172/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0055 - val_loss: 0.0059
# Epoch 173/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 174/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0054 - val_loss: 0.0058
# Epoch 175/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0054 - val_loss: 0.0058
# Epoch 176/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0054 - val_loss: 0.0058
# Epoch 177/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0054 - val_loss: 0.0058
# Epoch 178/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0054 - val_loss: 0.0057
# Epoch 179/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0054 - val_loss: 0.0058
# Epoch 180/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0053 - val_loss: 0.0058
# Epoch 181/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0053 - val_loss: 0.0057
# Epoch 182/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0053 - val_loss: 0.0057
# Epoch 183/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 184/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 185/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0052 - val_loss: 0.0056
# Epoch 186/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 187/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0052 - val_loss: 0.0057
# Epoch 188/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0052 - val_loss: 0.0056
# Epoch 189/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0051 - val_loss: 0.0055
# Epoch 190/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0051 - val_loss: 0.0055
# Epoch 191/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0051 - val_loss: 0.0055
# Epoch 192/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0051 - val_loss: 0.0055
# Epoch 193/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0051 - val_loss: 0.0054
# Epoch 194/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0050 - val_loss: 0.0054
# Epoch 195/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0050 - val_loss: 0.0054
# Epoch 196/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0050 - val_loss: 0.0054
# Epoch 197/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0050 - val_loss: 0.0054
# Epoch 198/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0050 - val_loss: 0.0054
# Epoch 199/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0049 - val_loss: 0.0053
# Epoch 200/200
# 115/115 [==============================] - 1s 6ms/step - loss: 0.0049 - val_loss: 0.0053
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 258, 540, 1)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 258, 540, 32)      320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 129, 270, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 129, 270, 32)      9248
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 258, 540, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 258, 540, 1)       289
# =================================================================
# Total params: 9,857
# Trainable params: 9,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
preds = autoencoder_model.predict(x_test)
print(preds)
# Out:
# [[[[0.9510725 ]
#    [0.99785036]
#    [0.9861305 ]
#    ...
#    [0.9892435 ]
#    [0.98760366]
#    [0.9462962 ]]
#
#   [[0.9908533 ]
#    [0.9998706 ]
#    [0.99795055]
#    ...
#    [0.99932945]
#    [0.9990665 ]
#    [0.9759663 ]]
#
#   [[0.986549  ]
#    [0.99974096]
#    [0.9937087 ]
#    ...
#    [0.99660623]
#    [0.9962827 ]
#    [0.9312701 ]]
#
#   ...
#
#   [[0.98051834]
#    [0.99967283]
#    [0.9963186 ]
#    ...
#    [0.9946972 ]
#    [0.9956387 ]
#    [0.9510622 ]]
#
#   [[0.9795465 ]
#    [0.99971676]
#    [0.99845123]
#    ...
#    [0.9986779 ]
#    [0.9980973 ]
#    [0.96085256]]
#
#   [[0.81370866]
#    [0.96644235]
#    [0.92286956]
#    ...
#    [0.95834804]
#    [0.94578207]
#    [0.8074591 ]]]
#
#
#  [[[0.9551027 ]
#    [0.9985376 ]
#    [0.9909113 ]
#    ...
#    [0.98800236]
#    [0.98644245]
#    [0.9441023 ]]
#
#   [[0.99220073]
#    [0.9999317 ]
#    [0.99907863]
#    ...
#    [0.999236  ]
#    [0.99902034]
#    [0.9754356 ]]
#
#   [[0.98873043]
#    [0.99984854]
#    [0.99688166]
#    ...
#    [0.9964542 ]
#    [0.99657726]
#    [0.937467  ]]
#
#   ...
#
#   [[0.9886329 ]
#    [0.9999056 ]
#    [0.9991014 ]
#    ...
#    [0.9970781 ]
#    [0.9960791 ]
#    [0.9516181 ]]
#
#   [[0.99049485]
#    [0.9999365 ]
#    [0.99961174]
#    ...
#    [0.99961925]
#    [0.99909973]
#    [0.97080827]]
#
#   [[0.85715795]
#    [0.98232055]
#    [0.9548683 ]
#    ...
#    [0.9784626 ]
#    [0.9645437 ]
#    [0.83673567]]]
#
#
#  [[[0.95359373]
#    [0.9983926 ]
#    [0.98736614]
#    ...
#    [0.88526595]
#    [0.89326304]
#    [0.8081888 ]]
#
#   [[0.9938891 ]
#    [0.9999565 ]
#    [0.99917126]
#    ...
#    [0.99045414]
#    [0.9905985 ]
#    [0.9169989 ]]
#
#   [[0.99497557]
#    [0.99996877]
#    [0.99910164]
#    ...
#    [0.99911034]
#    [0.9988396 ]
#    [0.9588813 ]]
#
#   ...
#
#   [[0.98148084]
#    [0.9997561 ]
#    [0.9973882 ]
#    ...
#    [0.9998329 ]
#    [0.9998579 ]
#    [0.98972034]]
#
#   [[0.9803119 ]
#    [0.99977857]
#    [0.99887437]
#    ...
#    [0.99938786]
#    [0.99769115]
#    [0.9239283 ]]
#
#   [[0.82061774]
#    [0.9718342 ]
#    [0.9376347 ]
#    ...
#    [0.8800901 ]
#    [0.63699424]
#    [0.5619325 ]]]
#
#
#  ...
#
#
#  [[[0.94325477]
#    [0.9972514 ]
#    [0.98242366]
#    ...
#    [0.9887128 ]
#    [0.98572123]
#    [0.9403741 ]]
#
#   [[0.9890703 ]
#    [0.99985135]
#    [0.9978179 ]
#    ...
#    [0.99924064]
#    [0.99880356]
#    [0.97227573]]
#
#   [[0.98852277]
#    [0.9998405 ]
#    [0.99648374]
#    ...
#    [0.9958335 ]
#    [0.99532753]
#    [0.9250089 ]]
#
#   ...
#
#   [[0.95576954]
#    [0.9984484 ]
#    [0.99025273]
#    ...
#    [0.9822384 ]
#    [0.9854076 ]
#    [0.91666365]]
#
#   [[0.9637709 ]
#    [0.99910605]
#    [0.996917  ]
#    ...
#    [0.998084  ]
#    [0.99686474]
#    [0.95051146]]
#
#   [[0.7629839 ]
#    [0.94058347]
#    [0.8952043 ]
#    ...
#    [0.96491504]
#    [0.94816947]
#    [0.80932677]]]
#
#
#  [[[0.94325477]
#    [0.9972514 ]
#    [0.98242366]
#    ...
#    [0.9887128 ]
#    [0.98572123]
#    [0.9403741 ]]
#
#   [[0.9890703 ]
#    [0.99985135]
#    [0.9978179 ]
#    ...
#    [0.99924123]
#    [0.998804  ]
#    [0.97227454]]
#
#   [[0.98852277]
#    [0.9998405 ]
#    [0.99648374]
#    ...
#    [0.9958305 ]
#    [0.99532497]
#    [0.9250142 ]]
#
#   ...
#
#   [[0.95576954]
#    [0.9984484 ]
#    [0.99025273]
#    ...
#    [0.21246678]
#    [0.38600788]
#    [0.66829586]]
#
#   [[0.9637709 ]
#    [0.99910605]
#    [0.996917  ]
#    ...
#    [0.9827014 ]
#    [0.97164595]
#    [0.8965473 ]]
#
#   [[0.7629839 ]
#    [0.94058347]
#    [0.8952043 ]
#    ...
#    [0.97506493]
#    [0.9450654 ]
#    [0.8143203 ]]]
#
#
#  [[[0.9503063 ]
#    [0.9981041 ]
#    [0.9879981 ]
#    ...
#    [0.98819494]
#    [0.9865109 ]
#    [0.9456039 ]]
#
#   [[0.9907049 ]
#    [0.99990284]
#    [0.9987979 ]
#    ...
#    [0.9993503 ]
#    [0.9991826 ]
#    [0.97814953]]
#
#   [[0.98927426]
#    [0.9998714 ]
#    [0.9977946 ]
#    ...
#    [0.99692416]
#    [0.997939  ]
#    [0.959721  ]]
#
#   ...
#
#   [[0.97931176]
#    [0.9997219 ]
#    [0.9974929 ]
#    ...
#    [0.99726224]
#    [0.99670315]
#    [0.9575838 ]]
#
#   [[0.9810131 ]
#    [0.99980104]
#    [0.9990635 ]
#    ...
#    [0.99877083]
#    [0.99854195]
#    [0.97150004]]
#
#   [[0.82628334]
#    [0.9739039 ]
#    [0.9427563 ]
#    ...
#    [0.9477181 ]
#    [0.9572922 ]
#    [0.83597064]]]]

# %%
x_test_0 = x_test[13] * 255.0
x_test_0 = x_test_0.reshape(258, 540)
x_test_1 = x_test[55] * 255.0
x_test_1 = x_test_1.reshape(258, 540)
x_test_2 = x_test[34] * 255.0
x_test_2 = x_test_2.reshape(258, 540)
x_test_3 = x_test[40] * 255.0
x_test_3 = x_test_3.reshape(258, 540)
fig = plt.figure(figsize=(15, 15))
fig.add_subplot(2,2,1)
plt.imshow(x_test_0,cmap='gray')
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(x_test_1,cmap='gray')
ax3 = fig.add_subplot(2,2,3)
ax3.imshow(x_test_2,cmap='gray')
ax4 = fig.add_subplot(2,2,4)
ax4.imshow(x_test_3,cmap='gray')

# %%
preds_0 = preds[13] * 255.0
preds_0 = preds_0.reshape(258, 540)
preds_1 = preds[55] * 255.0
preds_1 = preds_1.reshape(258, 540)
preds_2 = preds[34] * 255.0
preds_2 = preds_2.reshape(258, 540)
preds_3 = preds[40] * 255.0
preds_3 = preds_3.reshape(258, 540)
fig = plt.figure(figsize=(15, 15))
fig.add_subplot(2,2,1)
plt.imshow(preds_0,cmap='gray')
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(preds_1,cmap='gray')
ax3 = fig.add_subplot(2,2,3)
ax3.imshow(preds_2,cmap='gray')
ax4 = fig.add_subplot(2,2,4)
ax4.imshow(preds_3,cmap='gray')
